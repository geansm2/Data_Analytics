# %% [markdown]
# # 📈 Análise de Correlação: IDH vs. Mercado de Telecom (Pós-pago)
#
# Este notebook realiza a coleta, limpeza e análise de dados para investigar a relação entre o **Índice de Desenvolvimento Humano Municipal (IDHM)** e a penetração de **Planos Celulares Pós-pagos** por estado no Brasil.

# %% [markdown]
# ## 1. Setup e Coleta de Dados (Web Scraping)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# Configurações visuais
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = [12, 6]

# %% [markdown]
# ### 1.1 Coleta de Dados IDHM por Cidade
# Extraindo os dados mais recentes do Atlas Brasil / PNUD.

# %%
# URL do PNUD (Rankings IDHM)
url_idh = 'https://www.br.undp.org/content/brazil/pt/home/idh0/rankings/idhm-municipios-2010.html'

try:
    tabelas_idh = pd.read_html(url_idh)
    idh = tabelas_idh[0]
    
    # Limpeza Inicial
    # Separar Cidade da UF: "Cidade (UF)"
    idh[['Município', 'UF']] = idh['Município'].str.extract(r'^(.*)\s?\((.*)\)$')
    
    # Limpeza de valores do IDHM
    # Garantindo que seja numérico (converte 0,700 para 0.7)
    idh['IDHM_2010'] = idh['IDHM 2010'].astype(str).str.replace(',', '.').astype(float)
    
    # Mantendo apenas colunas de interesse
    idh = idh[['Município', 'UF', 'IDHM_2010']]
    print(f"Sucesso! {len(idh)} cidades carregadas.")
except Exception as e:
    print(f"Erro ao coletar IDH: {e}")

# %% [markdown]
# ### 1.2 Coleta de Dados Móveis (Teleco)
# Buscando o número total de acessos pós-pagos por Unidade Federativa.

# %%
url_teleco = 'https://www.teleco.com.br/pospago_uf.asp'

try:
    # Método robusto: ler todas as tabelas e filtrar a que contém 'UF' e 'Total'
    tabelas = pd.read_html(url_teleco)
    
    df_final_pos = pd.DataFrame()
    for t in tabelas:
        if 'UF' in t.columns and 'Total' in t.columns:
            df_final_pos = pd.concat([df_final_pos, t[['UF', 'Total']]])
    
    # Removendo duplicatas e totais gerais (como 'Brasil')
    df_final_pos = df_final_pos.dropna().drop_duplicates()
    df_final_pos = df_final_pos[df_final_pos['UF'].str.len() == 2]
    
    # Limpeza numérica: remover pontos e converter para int
    df_final_pos['Acessos_Pos_Pago'] = df_final_pos['Total'].astype(str).str.replace('.', '', regex=False).astype(int)
    
    print(f"Sucesso! {len(df_final_pos)} estados processados.")
except Exception as e:
    print(f"Erro ao coletar Teleco: {e}")

# %% [markdown]
# ## 2. Integração e Limpeza de Dados

# %%
# Agrupando IDH por Estado (Média)
idh_uf = idh.groupby('UF')['IDHM_2010'].mean().reset_index()

# Merge das Tabelas
df_final = pd.merge(df_final_pos, idh_uf, on='UF')

df_final.head()

# %% [markdown]
# ## 3. Visualização de Resultados

# %% [markdown]
# ### 3.1 Ranking de Estados por Acessos Pós-pagos

# %%
df_sorted = df_final.sort_values('Acessos_Pos_Pago', ascending=False)
sns.barplot(data=df_sorted, x='UF', y='Acessos_Pos_Pago', palette='viridis')
plt.title('Acessos Pós-pagos por Estado')
plt.show()

# %% [markdown]
# ### 3.2 Correlação: IDH Médio vs. Acessos Celulares
# Será que estados com maior IDH possuem maior volume de planos pós-pagos?

# %%
sns.regplot(data=df_final, x='IDHM_2010', y='Acessos_Pos_Pago')
plt.title('Correlação IDH vs. Penetração Pós-pago')
plt.xlabel('IDH Médio do Estado')
plt.ylabel('Total de Acessos (Milhões)')
plt.show()

# %% [markdown]
# ## 4. Conclusão
# A análise demonstra que há uma correlação positiva entre o desenvolvimento econômico/social e a adoção de serviços móveis avançados, embora o volume populacional de cada estado seja o fator de maior peso no total de acessos.
